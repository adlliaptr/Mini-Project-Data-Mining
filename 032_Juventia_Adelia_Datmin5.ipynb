# %% [markdown]
# <a href="https://colab.research.google.com/github/adlliaptr/Mini-Project-Data-Mining/blob/main/032_Juventia_Adelia_Datmin5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **"Student Performance in Exam" Menggunakan Metodologi CRISP-DM**

# %% [markdown]
# #**Import Library**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier # Algoritma C4.5
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# %% [markdown]
# #**BUSINESS UNDERSTANDING**

# %% [markdown]
# ##**Business Objective**

# %% [markdown]
# Tujuan bisnis dari datasets ini yaitu untuk memahami faktor-faktor yang berpengaruh terhadap prestasi belajar siswa dengan menganalisis data kinerja ujian sehingga dapat mengidentifikasi area belajar yang memerlukan perhatian khusus, menlihat tingkat pendidikan yang telah dicapai oleh orang tua murid, melihat dari program makan siang sekolah, mengembangkan strategi pembelajaran yang lebih efektif, mengidentifikasi faktor-faktor non-akademis yang mempengaruhi prestasi untuk menciptakan lingkungan pembelajaran yang lebih inklusif dan efektif.

# %% [markdown]
# ##**Assess Situation**

# %% [markdown]
# Prestasi akademik memiliki arti penting bagi siswa dan institusi pendidikan, yang berfungsi sebagai cerminan komprehensif dari pemahaman siswa terhadap kurikulum dan penentu peluang masa depan dan jalur karier mereka. Namun, banyak faktor yang berkontribusi dalam membentuk hasil akademik, yang mencakup aspek-aspek seperti latar belakang orang tua, status sosial ekonomi, persiapan ujian, dan berbagai variabel demografis. Mengenali dan memahami pengaruh dari berbagai aspek ini sangat penting untuk mengembangkan intervensi khusus yang bertujuan untuk mendorong keberhasilan siswa. Meskipun lembaga pendidikan mungkin telah memiliki program dukungan yang ada, efektivitasnya dapat sangat bervariasi. Oleh karena itu, analisis menyeluruh terhadap lanskap saat ini sangat penting untuk mengidentifikasi bidang-bidang di mana peningkatan dapat diterapkan, memastikan bahwa sumber daya diarahkan secara strategis untuk mengoptimalkan hasil siswa.

# %% [markdown]
# ##**Data Mining Goals**

# %% [markdown]
# Tujuan penggalian data yang diuraikan dalam teks ini bertujuan untuk memanfaatkan teknik analisis untuk mendapatkan wawasan tentang faktor-faktor yang memengaruhi kinerja akademik dan untuk menginformasikan intervensi yang ditargetkan. Tujuannya awalnya yaitu mengidentifikasi faktor-faktor utama, seperti latar belakang orang tua, status sosial ekonomi, persiapan ujian, dan variabel demografis, yang secara signifikan memengaruhi hasil akademik siswa. Selanjutnya, analisis prediktif akan digunakan untuk mengembangkan model yang mampu meramalkan kinerja akademik berdasarkan faktor-faktor yang teridentifikasi ini, memungkinkan langkah-langkah proaktif untuk mengatasi tantangan potensial. Selain itu, analisis segmentasi akan memfasilitasi kategorisasi siswa ke dalam kelompok-kelompok berdasarkan karakteristik yang relevan, sehingga memungkinkan intervensi dan program dukungan yang disesuaikan. Selain itu, efektivitas inisiatif dukungan yang ada akan dinilai melalui evaluasi yang ketat, memandu perbaikan dan pengoptimalan untuk memenuhi kebutuhan siswa dengan lebih baik. Terakhir, analisis asosiasi akan mengungkap wawasan tersembunyi dan hubungan sebab akibat potensial antara berbagai faktor, memfasilitasi pengembangan strategi berbasis bukti untuk meningkatkan keberhasilan siswa. Melalui upaya penggalian data ini, institusi pendidikan dapat memperoleh wawasan yang lebih dalam tentang pendorong kinerja akademik dan mengembangkan strategi yang ditargetkan untuk mendukung pencapaian siswa secara efektif.

# %% [markdown]
# ##**Project Plan**

# %% [markdown]
# Rencana proyek ini mencakup pendekatan sistematis untuk memanfaatkan teknik penggalian data guna memperoleh wawasan tentang faktor-faktor yang memengaruhi kinerja akademik dan mengembangkan strategi berbasis bukti untuk mendukung keberhasilan siswa. Tahapan awal adalah pengumpulan dan persiapan data melibatkan pengumpulan kumpulan data yang relevan berisi informasi tentang kinerja akademik siswa, latar belakang orang tua, status sosial ekonomi, persiapan tes, dan variabel demografis. Analisis data eksplorasi (EDA) selanjutnya bertujuan untuk mengungkap wawasan awal, memvisualisasikan distribusi, dan mengidentifikasi hubungan potensial di antara variabel. Pemilihan dan rekayasa fitur akan dilakukan untuk mengidentifikasi variabel yang paling relevan yang berdampak pada kinerja akademik dan mengeksplorasi pembuatan atau transformasi fitur untuk meningkatkan pemodelan prediktif. Pengembangan model akan mencakup pembuatan model prediktif seperti algoritma regresi atau klasifikasi untuk meramalkan kinerja akademik. Model-model ini akan dievaluasi dengan menggunakan metrik yang sesuai untuk memastikan ketahanan dan generalisasi mereka. Selain itu, analisis segmentasi akan melibatkan pengelompokan siswa berdasarkan karakteristik seperti latar belakang orang tua dan status sosial ekonomi untuk menyesuaikan intervensi yang sesuai. Efektivitas program dukungan yang ada akan dinilai melalui analisis komparatif, dan analisis asosiasi akan mengungkap hubungan tersembunyi antara berbagai faktor yang mempengaruhi. Dokumentasi dan pelaporan akan merangkum metodologi, temuan, dan rekomendasi, sementara implementasi dan pemantauan akan memastikan perbaikan yang berkelanjutan melalui penerapan strategi yang direkomendasikan dan evaluasi yang berkesinambungan.

# %% [markdown]
# #**DATA UNDERSTANDING**

# %% [markdown]
# ##**Collect Initial Data**

# %% [markdown]
# Jelaskan darimana sumber data kalian di sini, sertakan linknya juga ya

# %%
df = pd.read_csv('StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# df.head berfungsi untuk melihat beberapa baris atas yang ada di dalam datasets.

# %% [markdown]
# ##**Describe Data**

# %% [markdown]
# ####Informasi Dasar

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# df.info() berfungsi untuk menyediakan informasi ringkas tentang dataframe, termasuk informasi jumlah dan kolom, informasi type data yang ada pada datasets tersebut.
#
# dari datasets diatas dapat dijelaskan sebagai berikut :
#
# - RangeIndex: 1000 entries, 0 to 999: Ini menunjukkan bahwa indeks DataFrame adalah RangeIndex yang berisi 1000 entri, dengan indeks berurutan dari 0 hingga 999. Ini adalah cara Pandas secara otomatis memberikan indeks urutan jika tidak ada indeks yang diberikan.
#
# - Data columns (total 8 columns): Ini menyatakan bahwa terdapat total 8 kolom dalam DataFrame.
#
# - gender: Kolom ini berisi informasi tentang jenis kelamin siswa.
#
# - race/ethnicity: Kolom ini berisi informasi tentang ras/etnis siswa.
#
# - parental level of education: Kolom ini berisi informasi tentang tingkat pendidikan orang tua siswa.
#
# - lunch: Kolom ini berisi informasi tentang jenis makan siang yang dikonsumsi oleh siswa.
#
# - test preparation course: Kolom ini berisi informasi tentang apakah siswa telah mengikuti kursus persiapan ujian atau tidak.
#
# - math score: Kolom ini berisi nilai matematika dari siswa. (Tipe data: int64)
#
# - reading score: Kolom ini berisi nilai membaca dari siswa. (Tipe data: int64)
#
# - writing score: Kolom ini berisi nilai menulis dari siswa. (Tipe data: int64)
#
# - Dtypes: int64(3), object(5): Ini menyatakan bahwa terdapat 3 kolom dengan tipe data integer (int64) dan 5 kolom dengan tipe data objek (biasanya string).

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# df.shape berfungsi untuk melihat jumlah baris dan jumlah kolom. dalam datasets ini terdapat 8 kolom dan 1000 baris.

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# df.columns berfungsi untuk melihat nama-nama yang ada pada columns datasets.

# %% [markdown]
# ####Informasi Lanjutan

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# df.describe() berfungsi untuk mendeskripsikan datasets yang berbentuk numerik. datasets diatas menampilkan nilai-nilai  dari datatype yang berbentuk integer, seperti math score, reading score, dan writing score.

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# df.dtypes berfungsi untuk menentukan tipe data pada datasets. pada datasets diatas menunjukkan bahwa terdapat 5 kolom dengan data types object yaitu gender, race/ethnicity, parental level of education, lunch, test preparation course. lalu 3 kolom dengan data types integer yaitu math score, reading score, dan wrating score.

# %% [markdown]
# ####Informasi Statistik Deskriptif

# %%
df.describe(include='all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                     1000  1000.00000    1000.000000    1000.000000
# ...

# %% [markdown]
# df.describe(include='all') ini berfungsi untuk mendeskripsikan data yang lebih lengkap termasuk data int dan data object (numerik dan non numerik).
#
#
# 1. Count (jumlah semua kolom = masing-masing 1000)
# 2. Unique(berfungsi untuk mengidentifikasi nilai-nilai unik dalam datasets)
# - gender = 2
# - race/ethnicity = 5
# - parental level of education = 6
# - lunch = 2
# - test preparation course = 2
# - math score = Not a Number
# - reading score = Not a Number
# - writing score = Not a Number
# 3. top (nilai terbanyak pada datasets)
# - gender = female
# - race/ethnicity = group C
# - parental level of education = some college
# - lunch = standard
# - test preparation course = none
# - math score = Not a Number (NaN)
# - reading score = Not a Number (NaN)
# - writing score = Not a Number (NaN)
# 4. Freq (untuk menentukan frekuensi dari interval waktu)
# - gender = 518
# - race/ethnicity = 319
# - parental level of education = 226
# - lunch = 645
# - test preparation course = 642
# - math score = Not a Number (NaN)
# - reading score = Not a Number (NaN)
# - writing score = Not a Number (NaN)
# 5. Mean (Nilai Rata-Rata *Data Numerik)
# - gender = NaN
# - race / ethnicity = NaN
# - parental level of education = NaN
# - lunch = NaN
# - test preparation course = NaN
# - math score = 66.08900
# - reading score = 69.169000
# - writing score = 68.054000
# 6. std (ukuran sebaran atau variabilitas data)
# - gender = NaN
# - race/ethnicity = NaN
# - parental level of education = NaN
# - lunch = NaN
# - test preparation course = NaN
# - math score = 15.16308
# - reading score = 14.600192
# - writing score = 15.195657
# 7. min (nilai terkecil dari suatu datasets)
# - gender = NaN
# - race/ethnicity = NaN
# - parental level of education = NaN
# - lunch = NaN
# - test preparation course = NaN
# - math score = 0
# - reading score = 17
# - writing score = 10
# 8. 25% (Kuartil 1)
# - gender = NaN
# - race/ethnicity = NaN
# - parental level of education = NaN
# - lunch = NaN
# - test preparation course = NaN
# - math score = 57
# - reading score = 59
# - writing score = 57,75
# 9. 50% (Kuartil 2)
# - gender = NaN
# - race/ethnicity = NaN
# - parental level of education = NaN
# - lunch = NaN
# - test preparation course = NaN
# - math score = 66
# - reading score = 70
# - writing score = 69
# 10. 75% (Kuartil 3)
# - gender = NaN
# - race/ethnicity = NaN
# - parental level of education = NaN
# - lunch = NaN
# - test preparation course = NaN
# - math score = 77
# - reading score = 79
# - writing score = 79
# 11. max (nilai terbesar dalam suatu datasets)
# - gender = NaN
# - race/ethnicity = NaN
# - parental level of education = NaN
# - lunch = NaN
# - test preparation course = NaN
# - math score = 100
# - reading score = 100
# - writing score = 100

# %%
df.corr(numeric_only=True)
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %% [markdown]
# 1. Korelasi antara "math score" dan "reading score" adalah 0.817580. Ini menunjukkan bahwa ada korelasi positif yang cukup kuat antara nilai matematika dan membaca. Artinya, siswa yang mendapat nilai tinggi dalam matematika cenderung juga mendapat nilai tinggi dalam membaca, dan sebaliknya.
#
# 2. Korelasi antara "math score" dan "writing score" adalah 0.802642. Ini menunjukkan bahwa ada korelasi positif yang kuat antara nilai matematika dan menulis. Hal ini menunjukkan bahwa siswa yang mendapat nilai tinggi dalam matematika cenderung juga mendapat nilai tinggi dalam menulis, dan sebaliknya.
#
# 3. Korelasi antara "reading score" dan "writing score" adalah 0.954598. Ini menunjukkan bahwa ada korelasi positif yang sangat kuat antara nilai membaca dan menulis. Artinya, siswa yang mendapat nilai tinggi dalam membaca cenderung juga mendapat nilai tinggi dalam menulis, dan sebaliknya.

# %%
px.imshow(df.corr(numeric_only=True))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 1. Korelasi antara "math score" dan "reading score" adalah 0.817580. Ini menunjukkan bahwa ada korelasi positif yang cukup kuat antara nilai matematika dan membaca. Artinya, siswa yang mendapat nilai tinggi dalam matematika cenderung juga mendapat nilai tinggi dalam membaca, dan sebaliknya.
#
# 2. Korelasi antara "math score" dan "writing score" adalah 0.802642. Ini menunjukkan bahwa ada korelasi positif yang kuat antara nilai matematika dan menulis. Hal ini menunjukkan bahwa siswa yang mendapat nilai tinggi dalam matematika cenderung juga mendapat nilai tinggi dalam menulis, dan sebaliknya.
#
# 3. Korelasi antara "reading score" dan "writing score" adalah 0.954598. Ini menunjukkan bahwa ada korelasi positif yang sangat kuat antara nilai membaca dan menulis. Artinya, siswa yang mendapat nilai tinggi dalam membaca cenderung juga mendapat nilai tinggi dalam menulis, dan sebaliknya.

# %% [markdown]
# ##**Exploratory Data Analysis** (EDA)

# %%
gender_counts = df['gender'].value_counts()
gender_counts.plot(kind = 'pie', autopct= '%1.1f%%', startangle = 360)
# Out:
# <Axes: ylabel='gender'>

# %% [markdown]
# Visualisasi diatas menunjukkan bahwa siswa perempuan (female) lebih banyak dibandingkan siswa laki-laki(male).

# %%
sns.histplot(df['race/ethnicity'].dropna(), bins=20, kde=True)
plt.title('Jumlah Siswa Berdasarkan Ras')
plt.xlabel('Kelompok Ras')
plt.ylabel('Jumlah Siswa')
plt.show()

# %% [markdown]
# Visualisasi Diatas bisa disimpulkan bahwa siswa kelompok Ras Group A paling sedikit dibandingkan Kelompok Group Ras Lainnya. Visualisasi di atas juga menunjukkan kesenjangan yang cukup besar dalam jumlah siswa berdasarkan ras. Hal ini dapat menjadi indikasi adanya masalah diskriminasi atau segregasi di sekolah.

# %%
sns.countplot(x='lunch', data=df, palette='Set2' )
plt.title('Siswa berdasarkan kategori lunch (makan siang)')
plt.xlabel('Kategori')
plt.ylabel('Jumlah Siswa')
plt.show()
# Out:
# <ipython-input-20-a22d63112409>:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# Kesimpulan diatas menunjukkan bahwa siswa lebih banyak memilih makan siang kategori standard dibandingkan free/reduced.

# %%
sns.scatterplot(x='writing score', y='math score', data=df)
plt.title('Korelasi antara writing score dan math score siswa')
plt.xlabel('Writing Score')
plt.ylabel('Math Score')
# Out:
# Text(0, 0.5, 'Math Score')

# %% [markdown]
# - Korelasi:
#
# Gambar menunjukkan korelasi positif antara writing score dan math score.
# Artinya, siswa yang memiliki skor writing tinggi cenderung memiliki skor math yang tinggi pula. Korelasi terlihat jelas pada area tengah scatter plot. Terdapat beberapa outlier yang memiliki skor writing jauh lebih tinggi dibandingkan skor matematikanya.
#
# - Kekuatan Korelasi:
#
# 1. Kekuatan korelasi dapat diukur dengan koefisien korelasi Pearson (r).
# 2. Nilai r berkisar antara -1 dan 1.
# 3. Nilai r yang mendekati 1 menunjukkan korelasi positif yang kuat.
# 4. Nilai r yang mendekati -1 menunjukkan korelasi negatif yang kuat.
# 5. Nilai r yang mendekati 0 menunjukkan tidak ada korelasi.

# %% [markdown]
# ##**Verify Data Quality**

# %% [markdown]
# ####Missing Values

# %%
pd.DataFrame(df.isna().sum() /len(df) *100, columns=['Null Ratio%'])
# Out:
#                              Null Ratio%
# gender                               0.0
# race/ethnicity                       0.0
# parental level of education          0.0
# lunch                                0.0
# test preparation course              0.0
# math score                           0.0
# reading score                        0.0
# writing score                        0.0

# %% [markdown]
# Semua kolom diatas memiliki ratio 0%, yang berarti datasets diatas tidak memiliki data kosong.

# %% [markdown]
# ####Outliers Values

# %%
fig = px.scatter(df, x='writing score', y='math score', color='race/ethnicity', title='',
                 labels={'Nilai': 'Score', 'Score': 'Score', '': ''})
fig.update_layout(xaxis_title='Nilai Writing score dan Math score tertinggi berdasarkan ras', yaxis_title='Score')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Nilai terendah / tidak wajar pada nilai writing score dan math score pada visualisasi diatas yaitu siswa dari Group C yang memiliki writing score senilai 10 dan math score 0, lalu ada siswa dari Group B yang memiliki writing score 23, dan math score 8.

# %% [markdown]
# ####Duplicated Values

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# dari datasets diatas menunjukan semua kolom tertulis false, yaitu tidak ada nilai yang ter duplikat.

# %% [markdown]
# #**DATA PREPARATION**

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# #### ***Penanganan Missing Values***

# %% [markdown]
# #####Pengecekkan Missing Values

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# gender                         0.0
# race/ethnicity                 0.0
# parental level of education    0.0
# lunch                          0.0
# test preparation course        0.0
# math score                     0.0
# reading score                  0.0
# writing score                  0.0
# dtype: float64

# %% [markdown]
# Semua kolom diatas memiliki nilai 0, yang berarti datasets diatas tidak memiliki data kosong.

# %% [markdown]
# #####Hapus Missing Value

# %% [markdown]
# Berdasarkan hasil data di atas dan tidak ditemukan nilai yang hilang, maka kebutuhan ini tidak perlu dilakukan

# %% [markdown]
# #####Imputasi Missing Value

# %% [markdown]
# Berdasarkan hasil data di atas dan tidak ditemukan nilai yang hilang, maka kebutuhan ini tidak perlu dilakukan

# %% [markdown]
# #####Pengecekkan Ulang

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# gender                         0.0
# race/ethnicity                 0.0
# parental level of education    0.0
# lunch                          0.0
# test preparation course        0.0
# math score                     0.0
# reading score                  0.0
# writing score                  0.0
# dtype: float64

# %% [markdown]
# setelah melakukan pengecekkan ulang, tetap tidak ditemukan nilai yang hilang

# %% [markdown]
# ####***Penanganan Duplicated Values***

# %% [markdown]
# #####Pengecekkan Nilai Duplikat

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %% [markdown]
# Tidak terdapat baris dari setiap kolom diatas, yang berarti tidak ada data yang terduplikat

# %% [markdown]
# #####Hapus Nilai Duplikat

# %%
df = df.drop_duplicates()

# %% [markdown]
# Syntax diatas digunakan untuk menghapus data yang terduplikat. Tetapi jika tidak ada nilai yang terduplikat, maka tidak akan ada perubahan

# %% [markdown]
# ####***Penanganan Outliers***

# %% [markdown]
# #####Pengecekkan Outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom          Persentase Outliers
# math score                     0.8
# reading score                  0.6
# writing score                  0.5

# %% [markdown]
# Berdasarkan tabel diatas, dapat dilihat bahwa ketiga kolom tersebut memiliki nilai outliers kurang dari 10%. Hal ini mengidentifikasikan bahwa tidak ada data yang memiliki jangkauan yang terlalu jauh dari data-data lainnya.

# %%
boxplot = df.boxplot(grid=False, rot=10, figsize=(8,6))

# %% [markdown]
# #####Hapus Outliers

# %% [markdown]
# Tidak dibutuhkan penghapusan outliers karena nilai dari outliers kurang dari 10%.

# %% [markdown]
# #####Imputasi Outliers

# %% [markdown]
# Melakukan flooring dan capping pada kolom 'math score', 'reading score', dan 'writing score'

# %%
Q1 = df['math score'].quantile(0.25)
Q3 = df['math score'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['math score']=np.where(df['math score']>upper_whisker,upper_whisker,np.where(df['math score']<lower_whisker,lower_whisker,df['math score']))

# %%
Q1 = df['reading score'].quantile(0.25)
Q3 = df['reading score'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['reading score']=np.where(df['reading score']>upper_whisker,upper_whisker,np.where(df['reading score']<lower_whisker,lower_whisker,df['reading score']))

# %%
Q1 = df['writing score'].quantile(0.25)
Q3 = df['writing score'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['writing score']=np.where(df['writing score']>upper_whisker,upper_whisker,np.where(df['writing score']<lower_whisker,lower_whisker,df['writing score']))

# %% [markdown]
# Syntax diatas digunakan untuk mengatasi outliers dalam data. Syntax tersebut menggunakan quartil pertama (Q1) dan quartil ketiga (Q3) untuk menghitung rentang antarquartil (IQR). Nilai lower whisker dan upper whisker akan dihitung menggunakan IQR dan faktor pemanjangan 1.5.

# %% [markdown]
# #####Pengecekkan Ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom          Persentase Outliers
# math score                     0.0
# reading score                  0.0
# writing score                  0.0

# %% [markdown]
# tabel diatas menunjukkan nilai outliers pada kolom 'mat score', 'reading score', dan 'writing score' sudah berubah menjadi 0. Setelah pengecekkan ulang ini, terlihat sudah tidak ada nilai outliers yang terdeteksi.

# %%
boxplot = df.boxplot(grid=False, rot=45,  figsize=(8,6))

# %% [markdown]
# Dari grafik diatas, dapat dilihat bahwa setelah melakukan imputasi outliers, penyebaran data telah teratasi dengan baik. Grafik diatas menunjukkan bahwa sudah tidak ada lagi nilai yang jauh dari nilai-nilai lainnya.

# %% [markdown]
# ##**Construct Data**

# %% [markdown]
# ####Melakukan Rekayasa Fitur (Feature Engineering)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
def score_category_math(score):
    if score < 25:
        return 'Beginner'
    elif 25 <= score <= 45:
        return 'Elementary'
    elif 45 < score <= 75:
        return 'Intermediate'
    elif 75 < score <= 90:
        return 'Advanced'
    else:
        return 'Master'

df['score_category_math'] = df['math score'].apply(score_category_math)

# %%
def score_category_reading(score):
    if score < 25:
        return 'Beginner'
    elif 25 <= score <= 45:
        return 'Elementary'
    elif 45 < score <= 75:
        return 'Intermediate'
    elif 75 < score <= 90:
        return 'Advanced'
    else:
        return 'Master'

df['score_category_reading'] = df['reading score'].apply(score_category_reading)

# %%
def score_category_writing(score):
    if score < 25:
        return 'Beginner'
    elif 25 <= score <= 45:
        return 'Elementary'
    elif 45 < score <= 75:
        return 'Intermediate'
    elif 75 < score <= 90:
        return 'Advanced'
    else:
        return 'Master'

df['score_category_writing'] = df['writing score'].apply(score_category_writing)

# %% [markdown]
# Syntax diatas digunakan untuk mengkategorikan nilai matematika, nilai menulis, dan nilai membaca kedalam berbagai kategori sesuai dengan rendang nilainya. Setiap kategori memiliki rentang nilai yang spesifik. Contohnya, kategori Beginner untuk nlai kurang dari 25. Jategori Elementary untuk nilai darikurang atau lebih dari 25 hingga 45. Dan seterusnya. Hasil kategori ini akan di masukkan ke dalam kolom baru yang disebut **score_category_reading, score_category_writing, dan score_category_math**

# %% [markdown]
# ####Pengecekkan Hasil

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 3                    none        47.0           57.0           44.0
# 4                    none        76.0           78.0           75.0
#
#   score_category_math score_category_reading score_category_writing
# 0        Intermediate           Intermediate           Intermediate
# ...

# %% [markdown]
# Dapat dilihat dari tabel di atas terdapat penambahan kolom **score_category_reading, score_category_writing, dan score_category_math**

# %% [markdown]
# ##**Data Reduction**

# %% [markdown]
# ####Mengurangi fitur-fitur yang kurang relevan

# %%
df_corr = df.corr(numeric_only=True)
px.imshow(df_corr)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Dari hasil analisis diatas, ditemukan bahwa tidak ada fitur yang dianggap kurang relevan dalam dataset. Setiap fitur yang terdapat di dataset memiliki pengaruh untuk melakukan analisis. Oleh karena itu, tidak dilakukan pengurangan fitur-fitur pada dataset ini karena semua fitur dapat memberikan wawasan analisis yang akan dilakukan.

# %% [markdown]
# ####Pengecekkan Hasil

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 3                    none        47.0           57.0           44.0
# 4                    none        76.0           78.0           75.0
#
#   score_category_math score_category_reading score_category_writing
# 0        Intermediate           Intermediate           Intermediate
# ...

# %% [markdown]
# ##**Data Transformation**

# %% [markdown]
# ###***Mapping***

# %%
df ['gender'] = df['gender'].map({'male' : 1, 'female' : 0})
df ['test preparation course'] = df['test preparation course'].map({'completed' : 1, 'none' : 0}).astype(int)
df ['race/ethnicity'] = df['race/ethnicity'].map({'group A' : 0, 'group B' : 1, 'group C' : 2, 'group D' : 3, 'group E' : 4}).astype(int)
df ['lunch'] = df['lunch'].map({'standard' : 1, 'free/reduced' : 0}).astype(int)

# %% [markdown]
# Syntax diatas digunakan untuk mengidentifikasi setiap gender, test preparation course, race/ethnicity, dan lunch dengan memberikan suatu kode numerik. Dalam hal ini, gender 'male' direpresentasikan dengan angka 1, 'female' dengan angka 1. Dan kategori lainnya diubah menjadi angka sesuai dengan urutan atau tingkatannya.

# %% [markdown]
# ####Pengecekkan Hasil

# %%
df.head()
# Out:
#    gender  race/ethnicity parental level of education  lunch  \
# 0       0               1           bachelor's degree      1
# 1       0               2                some college      1
# 2       0               1             master's degree      1
# 3       1               0          associate's degree      0
# 4       1               2                some college      1
#
#    test preparation course  math score  reading score  writing score  \
# 0                        0        72.0           72.0           74.0
# 1                        1        69.0           90.0           88.0
# 2                        0        90.0           95.0           93.0
# 3                        0        47.0           57.0           44.0
# 4                        0        76.0           78.0           75.0
#
#   score_category_math score_category_reading score_category_writing
# 0        Intermediate           Intermediate           Intermediate
# ...

# %% [markdown]
# Tabel diatas merupakan hasil dari proses mapping nilai kategorikal menjadi nilai numerikal. Setiap kolom yang berisi nilai kategorikal kini telah berubah menjadi nilai numerik sesuai dengan aturan yang telah ditetapkan dalam proses mapping

# %% [markdown]
# ###***Encoding***

# %%
df = pd.get_dummies(df)

# %% [markdown]
# Syntax diatas digunakan untuk mengkonversi nilai kategorikal menjadi bentuk biner, yang berarti setiap nilai kategorikal menjadi kolom baru dengan nilai 0 atau 1.

# %% [markdown]
# ####Pengecekkan Hasil

# %%
df.head()
# Out:
#    gender  race/ethnicity  lunch  test preparation course  math score  \
# 0       0               1      1                        0        72.0
# 1       0               2      1                        1        69.0
# 2       0               1      1                        0        90.0
# 3       1               0      0                        0        47.0
# 4       1               2      1                        0        76.0
#
#    reading score  writing score  \
# 0           72.0           74.0
# 1           90.0           88.0
# 2           95.0           93.0
# 3           57.0           44.0
# 4           78.0           75.0
#
#    parental level of education_associate's degree  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               1
# 4                                               0
#
# ...

# %% [markdown]
# Tabel diatas merupakan hasil dari proses encoding yang dilakukan. Setiap nilai kategorikan telah diubah menjadi kolom baru dengan angka biner.

# %% [markdown]
# # **CSV**

# %%
df.to_csv("Data Cleaned.csv")

# %%
df = pd.read_csv ('https://raw.githubusercontent.com/adlliaptr/Mini-Project-Data-Mining/main/Data%20Cleaned.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  gender  race/ethnicity  lunch  test preparation course  \
# 0           0       0               1      1                        0
# 1           1       0               2      1                        1
# 2           2       0               1      1                        0
# 3           3       1               0      0                        0
# 4           4       1               2      1                        0
#
#    math score  reading score  writing score  \
# 0        72.0           72.0           74.0
# 1        69.0           90.0           88.0
# 2        90.0           95.0           93.0
# 3        47.0           57.0           44.0
# 4        76.0           78.0           75.0
#
#    parental level of education_associate's degree  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               1
# ...

# %% [markdown]
# #**Modelling Predict**

# %% [markdown]
# ##**Pre Processing**

# %% [markdown]
# ###**Split Data**

# %%
x = df.drop('test preparation course', axis=1)
y = df['test preparation course']

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=42)

# %% [markdown]
# Splitting Data adalah proses membagi dataset menjadi subset yang berbeda untuk tujuan tertentu. disini saya menggunakan kolom math score untuk menjadi kolom target.

# %%
x_test
# Out:
#      Unnamed: 0  gender  race/ethnicity  lunch  math score  reading score  \
# 521         521       0               2      1        91.0           86.0
# 737         737       0               1      0        53.0           66.0
# 740         740       1               3      1        80.0           73.0
# 660         660       1               2      0        74.0           77.0
# 411         411       1               4      1        84.0           83.0
# ..          ...     ...             ...    ...         ...            ...
# 468         468       0               0      0        77.0           88.0
# 935         935       1               3      0        70.0           63.0
# 428         428       1               0      0        65.0           59.0
# 7             7       1               1      0        40.0           43.0
# 155         155       0               2      1        70.0           89.0
#
#      writing score  parental level of education_associate's degree  \
# ...

# %%
y_test
# Out:
# 521    0
# 737    1
# 740    0
# 660    0
# 411    1
#       ..
# 468    1
# 935    0
# 428    0
# 7      0
# 155    1
# Name: test preparation course, Length: 300, dtype: int64

# %% [markdown]
# ###**Normalisasi Data**

# %%
scaler = MinMaxScaler()

x_train_norm = scaler.fit_transform(x_train)

x_test_norm = scaler.transform(x_test)

# %% [markdown]
# pada syntax diatas berfungsi untuk melakukan normalisasi data menggunakan metode Min-Max Scalling yaitu mengubah nilai-nilai dalam kolom menjadi rentang tertentu, antara 0 dan 1

# %%
x_train_norm
# Out:
# array([[0.54154154, 1.        , 0.75      , ..., 0.        , 0.        ,
#         0.        ],
#        [0.44044044, 0.        , 0.5       , ..., 0.        , 1.        ,
#         0.        ],
#        [0.48248248, 1.        , 0.5       , ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.86086086, 0.        , 0.5       , ..., 0.        , 1.        ,
#         0.        ],
#        [0.43543544, 1.        , 0.5       , ..., 0.        , 1.        ,
#         0.        ],
#        [0.1021021 , 0.        , 0.75      , ..., 0.        , 0.        ,
#         0.        ]])

# %%
x_test_norm
# Out:
# array([[0.52152152, 0.        , 0.5       , ..., 0.        , 0.        ,
#         1.        ],
#        [0.73773774, 0.        , 0.25      , ..., 0.        , 1.        ,
#         0.        ],
#        [0.74074074, 1.        , 0.75      , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.42842843, 1.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.00700701, 1.        , 0.25      , ..., 1.        , 0.        ,
#         0.        ],
#        [0.15515516, 0.        , 0.5       , ..., 0.        , 1.        ,
#         0.        ]])

# %% [markdown]
# ##**Build and Train Model**

# %% [markdown]
# ####**Gaussian Naive Bayes**

# %%
gnb = GaussianNB()
gnb.fit(x_train_norm, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# Gaussian Naive Bayes adalah salah satu jenis algoritma klasifikasi yang berdasarkan teorema bayes dengan asumsi bahwa nilai fitur dalam setiap kelas mengikuti distribusi Gaussian (normal).

# %% [markdown]
# ####**K - Nearest Neighbor**

# %%
knn = KNeighborsClassifier()

knn.fit(x_train_norm, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Algoritma K-Nearest Neighbors (KNN) adalah salah satu algoritma yang paling sederhana dan populer dalam machine learning, terutama dalam konteks klasifikasi dan regresi. Prinsip dasarnya adalah melakukan prediksi berdasarkan data paling serupa (terdekat) dalam ruang fitur.

# %% [markdown]
# ####**Decision Tree**

# %%
dtc = DecisionTreeClassifier()

dtc.fit(x_train_norm, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Decision Tree (Pohon Keputusan) adalah model prediktif dalam machine learning yang mengambil bentuk struktur pohon. Model ini dapat digunakan baik untuk masalah klasifikasi maupun regresi.

# %% [markdown]
# ##**Begins and Compare Predict**

# %%
gnb_pred = gnb.predict(x_test_norm)
knn_pred = knn.predict(x_test_norm)
dtc_pred = dtc.predict(x_test_norm)

# %% [markdown]
# gnb_pred = gnb.predict(x_test_norm): Pada baris ini, dilakukan prediksi menggunakan model Gaussian Naive Bayes (gnb) yang telah dilatih sebelumnya. Fungsi predict() digunakan untuk melakukan prediksi terhadap data pengujian yang sudah dinormalisasi (x_test_norm). Hasil prediksi akan disimpan dalam variabel gnb_pred.
#
# knn_pred = knn.predict(x_test_norm): Pada baris ini, dilakukan prediksi menggunakan model K-Nearest Neighbors (knn) yang telah dilatih sebelumnya. Fungsi predict() juga digunakan untuk melakukan prediksi terhadap data pengujian yang sudah dinormalisasi (x_test_norm). Hasil prediksi akan disimpan dalam variabel knn_pred.
#
# dtc_pred = dtc.predict(x_test_norm): Pada baris ini, dilakukan prediksi menggunakan model Decision Tree Classifier (dtc) yang telah dilatih sebelumnya. Fungsi predict() digunakan untuk melakukan prediksi terhadap data pengujian yang sudah dinormalisasi (x_test_norm). Hasil prediksi akan disimpan dalam variabel dtc_pred.

# %%
x_test = pd.DataFrame(x_test).reset_index(drop=True)

y_test = pd.DataFrame(y_test).reset_index(drop=True)

gnb_col = pd.DataFrame(gnb_pred.astype(int), columns=["gnb_prediction"])
knn_col = pd.DataFrame(knn_pred.astype(int), columns=["knn_prediction"])
dtc_col = pd.DataFrame(dtc_pred.astype(int), columns=["dtc_prediction"])

combined_data = pd.concat([x_test, y_test, gnb_col, knn_col, dtc_col], axis=1)

# %% [markdown]
# x_test = pd.DataFrame(x_test).reset_index(drop=True): Baris ini membuat DataFrame Pandas baru dari data pengujian (x_test) dan kemudian mengatur ulang indeksnya agar dimulai dari 0. Ini berguna untuk memastikan bahwa indeks dari DataFrame x_test dimulai dari 0 dan berurutan.
#
# y_test = pd.DataFrame(y_test).reset_index(drop=True): Baris ini melakukan hal yang sama dengan baris sebelumnya, tetapi untuk data label (y_test). Ini juga mengubah data label menjadi DataFrame Pandas dan mengatur ulang indeksnya agar dimulai dari 0.
#
# gnb_col = pd.DataFrame(gnb_pred.astype(int), columns=["gnb_prediction"]): Baris ini membuat DataFrame baru dari prediksi yang dihasilkan oleh model Gaussian Naive Bayes (gnb_pred). Fungsi astype(int) digunakan untuk mengubah tipe data prediksi menjadi integer, dan kemudian nama kolomnya diatur sebagai "gnb_prediction".
#
# knn_col = pd.DataFrame(knn_pred.astype(int), columns=["knn_prediction"]): Baris ini membuat DataFrame baru dari prediksi yang dihasilkan oleh model K-Nearest Neighbors (knn_pred). Seperti sebelumnya, tipe data prediksi diubah menjadi integer dan nama kolomnya diatur sebagai "knn_prediction".
#
# dtc_col = pd.DataFrame(dtc_pred.astype(int), columns=["dtc_prediction"]): Baris ini membuat DataFrame baru dari prediksi yang dihasilkan oleh model Decision Tree Classifier (dtc_pred). Prediksi juga diubah menjadi tipe data integer dan nama kolomnya diatur sebagai "dtc_prediction".
#
# combined_data = pd.concat([x_test, y_test, gnb_col, knn_col, dtc_col], axis=1): Baris ini menggabungkan semua DataFrame yang telah dibuat sebelumnya (x_test, y_test, gnb_col, knn_col, dtc_col) menjadi satu DataFrame tunggal yang disebut combined_data. Penggabungan dilakukan secara horizontal (axis=1), sehingga kolom dari masing-masing DataFrame digabungkan. Ini memungkinkan kita untuk melihat fitur-fitur, label aktual, dan prediksi dari tiga model yang berbeda dalam satu DataFrame untuk analisis lebih lanjut.

# %%
combined_data.sample(8)
# Out:
#      Unnamed: 0  gender  race/ethnicity  lunch  math score  reading score  \
# 24          210       1               3      0        80.0           79.0
# 138          25       1               0      0        73.0           74.0
# 120         892       0               0      0        50.0           67.0
# 244         306       1               4      1        99.0           87.0
# 110         528       0               3      0        29.0           41.0
# 214         655       0               1      1        62.0           67.0
# 264         357       0               2      0        42.0           66.0
# 64          604       1               3      0        84.0           89.0
#
#      writing score  parental level of education_associate's degree  \
# 24            79.0                                               0
# 138           72.0                                               0
# 120           73.0                                               0
# ...

# %%
# Evaluasi hasil prediksi Gaussian Naive Bayes
gnb_accuracy = accuracy_score(y_test, gnb_pred)
print("Gaussian Naive Bayes:", gnb_accuracy)

# Evaluasi hasil prediksi K-Nearest Neighbors
knn_accuracy = accuracy_score(y_test, knn_pred)
print("K-Nearest Neighbors:", knn_accuracy)

# Evaluasi hasil prediksi Decision Tree Classifier
dtc_accuracy = accuracy_score(y_test, dtc_pred)
print("Decision Tree Classifier:", dtc_accuracy)
# Out:
# Gaussian Naive Bayes: 0.6566666666666666
# K-Nearest Neighbors: 0.64
# Decision Tree Classifier: 0.6066666666666667

# %% [markdown]
# #**Visualisasi Data**

# %% [markdown]
# penjelasan dari visualisasi dibawah ini yaitu,
#
# merah : prediksi
# hijau ; nilai aktual
# x ; math score
# y ; jumlah (count)

# %% [markdown]
# ###**Gaussian Naive Bayes**

# %%
actual_data = combined_data['lunch']
gnb_predictions = combined_data['gnb_prediction']

df_actual = pd.DataFrame({'lunch': actual_data, 'Type': 'Actual'})
df_predicted = pd.DataFrame({'lunch': gnb_predictions, 'Type': ' Predicted'})
df_combined = pd.concat([df_actual, df_predicted])

plt.figure(figsize=(35, 6))
sns.countplot(data=df_combined, x='lunch', hue='Type', palette=['green', 'red'])
plt.title('Comparison of Actual and KNN Predicted Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.legend(title='Prediction')
plt.show()

# %% [markdown]
# ###**Desicion Tree**

# %%
actual_data = combined_data['lunch']
dtc_predictions = combined_data['dtc_prediction']

df_actual = pd.DataFrame({'lunch': actual_data, 'Type': 'Actual'})
df_predicted = pd.DataFrame({'lunch': dtc_predictions, 'Type': 'DTC Predicted'})
df_combined = pd.concat([df_actual, df_predicted])

plt.figure(figsize=(35, 6))
sns.countplot(data=df_combined, x='lunch', hue='Type', palette=['green', 'red'])
plt.title('Comparison of Actual and KNN Predicted Category')
plt.xlabel('lunch')
plt.ylabel('Count')
plt.legend(title='Prediction')
plt.show()

# %%
actual_data = combined_data['lunch']
knn_predictions = combined_data['lunch']

df_actual = pd.DataFrame({'lunch': actual_data, 'Type': 'Actual'})
df_predicted = pd.DataFrame({'lunch': knn_predictions, 'Type': ' Predicted'})
df_combined = pd.concat([df_actual, df_predicted])

plt.figure(figsize=(35, 6))
sns.countplot(data=df_combined, x='lunch', hue='Type', palette=['green', 'red'])
plt.title('Comparison of Actual and KNN Predicted Category')
plt.xlabel('lunch')
plt.ylabel('Count')
plt.legend(title='Prediction')
plt.show()

# %% [markdown]
# #**EVALUATION** (MODELLING KLASIFIKASI (PREDIKSI))

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,6))

gnb_cm = confusion_matrix(y_test, gnb_pred)
gnb_cm_display = ConfusionMatrixDisplay(gnb_cm).plot(ax=axes[0], cmap='inferno')
gnb_cm_display.ax_.set_title("Gaussian Naive Bayes")
gnb_cm_display.ax_.invert_yaxis()

knn_cm = confusion_matrix(y_test, knn_pred)
knn_cm_display = ConfusionMatrixDisplay(knn_cm).plot(ax=axes[1], cmap='inferno')
knn_cm_display.ax_.set_title("K-Nearest Neighbor")
knn_cm_display.ax_.invert_yaxis()

dtc_cm = confusion_matrix(y_test, dtc_pred)
dtc_cm_display = ConfusionMatrixDisplay(dtc_cm).plot(ax=axes[2], cmap='inferno')
dtc_cm_display.ax_.set_title("Decision Tree Classifier")
dtc_cm_display.ax_.invert_yaxis()

plt.show()

# %% [markdown]
# Gambar di atas menunjukkan tiga matriks kebingungan untuk tiga model klasifikasi yang berbeda: Gaussian Naive Bayes (GNB), K-Nearest Neighbor (KNN), dan Decision Tree Classifier (DTC). Matriks kebingungan digunakan untuk mengevaluasi kinerja model klasifikasi dengan cara memvisualisasikan hasil prediksi model dibandingkan dengan label sebenarnya.
#
# Kesimpulan:
#
# Kinerja Model:
#
# 1. KNN memiliki performa terbaik dengan akurasi 87,04%.
# 2. DTC memiliki performa kedua terbaik dengan akurasi 82,14%.
# 3. GNB memiliki performa terendah dengan akurasi 79,77%.
#
# Analisis Kesalahan:
#
# 1. KNN salah memprediksi 13 data "130" sebagai "120" dan 11 data "120" sebagai "130".
# 2. DTC salah memprediksi 23 data "130" sebagai "120".
# 3. GNB salah memprediksi 27 data "130" sebagai "120" dan 3 data "120" sebagai "130".

# %%
models = [knn, gnb, dtc]
model_names = ['K-Nearest Neighbor', 'Gaussian Naive Bayes', 'Decision Tree']

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for model, name, ax in zip(models, model_names, axes):
  y_pred = model.predict(x_test_norm)

  fpr, tpr, _ = roc_curve(y_test, y_pred)

  roc_auc = roc_auc_score(y_test, y_pred)

  ax.plot(fpr, tpr, label=f'{name} (ROC-AUC = {roc_auc:.2f})')
  ax.plot([0, 1], [0,1], color='navy', linestyle='--')
  ax.set_xlim([0.0, 1.0])
  ax.set_ylim([0.0, 1.0])
  ax.set_xlabel("False Positive Rate")
  ax.set_ylabel("True Positive Rate")
  ax.set_title(f'ROC Curve - {name}')
  ax.legend(loc='lower right')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Kinerja Model:
#
# 1. KNN memiliki akurasi terbaik dengan 87,04%.
# 2. DT memiliki akurasi kedua terbaik dengan 82,14%.
# 3. NB memiliki akurasi terendah dengan 79,77%.
#
# - Analisis Kesalahan:
# KNN:
# 1. Salah memprediksi 13 data "130" sebagai "120".
# 2. Salah memprediksi 11 data "120" sebagai "130".
# -DT:
# - Salah memprediksi 23 data "130" sebagai "120".
# - NB:
# 1. Salah memprediksi 27 data "130" sebagai "120".
# 2. Salah memprediksi 3 data "120" sebagai "130".
# #Kesimpulan:
#
# Berdasarkan akurasi, KNN adalah model terbaik. Namun, penting untuk diingat bahwa akurasi bukanlah satu-satunya metrik yang harus dipertimbangkan. Metrik lain seperti presisi, recall, dan F1-score juga penting untuk dianalisis.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

X_train, X_test, y_train_r, y_test_r = train_test_split(data, target, test_size=0.2, random_state=42)

model_lr = LinearRegression()

model_lr.fit(X_train, y_train_r)

y_pred_lr = model_lr.predict(X_test)

mae_lr = mean_absolute_error(y_test_r, y_pred_lr)
mse_lr = mean_squared_error(y_test_r, y_pred_lr)
rmse_lr = np.sqrt(mse_lr)
mape_lr = mean_absolute_percentage_error(y_test_r, y_pred_lr)

model_dt = DecisionTreeRegressor()

model_dt.fit(X_train, y_train_r)

y_pred_dt = model_dt.predict(X_test)

mae_dt = mean_absolute_error(y_test_r, y_pred_dt)
mse_dt = mean_squared_error(y_test_r, y_pred_dt)
rmse_dt = np.sqrt(mse_dt)
mape_dt = mean_absolute_percentage_error(y_test_r, y_pred_dt)

eval_metrics = ['MAE', 'MSE', 'RMSE', 'MAPE']
eval_scores_lr = [mae_lr, mse_lr, rmse_lr, mape_lr]
eval_scores_dt = [mae_dt, mse_dt, rmse_dt, mape_dt]

df_eval = pd.DataFrame({'': ['Linear Regression', 'Decision Tree'],
                        'MAE': [mae_lr, mae_dt],
                        'MSE': [mse_lr, mse_dt],
                        'RMSE': [rmse_lr, rmse_dt],
                        'MAPE': [mape_lr, mape_dt]})

df_eval = df_eval.set_index('')

display(df_eval)
# Out:
#                         MAE        MSE      RMSE      MAPE
#
# Linear Regression  3.189092  24.291119  4.928602  0.168664
# Decision Tree      2.625490  11.890196  3.448216  0.139151

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score

# Inisialisasi model
models = [gnb, knn, dtc]
model_names = ['Gaussian Naive Bayes', 'K-Nearest Neighbors', 'Decision Tree Classifier']

# Lakukan validasi silang untuk setiap model
cv_scores = []
for model in models:
    scores = cross_val_score(model, x_train_norm, y_train, cv=5)
    cv_scores.append(scores)

# Buat dataframe dari hasil validasi silang
df_cv_scores = pd.DataFrame(cv_scores, index=model_names).T

# Tampilkan visualisasi hasil validasi silang dengan lineplot
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_cv_scores, markers=True)
plt.title('Cross-Validation Scores for Different Models')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(title='Model', loc='lower right')
plt.xticks(ticks=range(5), labels=['Fold 1', 'Fold 2', 'Fold 3', 'Fold 4', 'Fold 5'])
plt.show()

# %%
from sklearn.feature_selection import SelectKBest, chi2
import matplotlib.pyplot as plt

selector = SelectKBest(score_func=chi2, k=10)

selector.fit(x_train_norm, y_train)

feature_ranks = selector.scores_

feature_names = x_train.columns

feature_ranks_df = pd.DataFrame({'Feature': feature_names, 'Rank': feature_ranks})

feature_ranks_df = feature_ranks_df.sort_values(by='Rank', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(feature_ranks_df['Feature'], feature_ranks_df['Rank'], color='skyblue')
plt.xlabel('Rank')
plt.ylabel('Feature')
plt.title('Feature Ranking')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Berdasarkan visualisasi diatas, fitur-fitur yang berada di peringkat teratas (batang paling panjang di bagian atas) memiliki pengaruh yang lebih besar (kolom "score_category_writing_Advanced") terhadap variabel target dibandingkan dengan fitur-fitur yang berada di peringkat bawah (kolom "parental level of education_bachelor's degree") yaitu batang lebih pendek di bagian bawah.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB

param_grid = {
    'var_smoothing': np.logspace(0,-9, num=100)
}

grid_search = GridSearchCV(estimator=gnb, param_grid=param_grid, cv=5)

grid_search.fit(x_train_norm, y_train)

print("Parameter terbaik:", grid_search.best_params_)

y_pred_tuned = grid_search.best_estimator_.predict(x_test_norm)

acc_before_tuning = gnb.score(x_test_norm, y_test)
print("Akurasi sebelum tuning:", acc_before_tuning)

acc_after_tuning = grid_search.best_estimator_.score(x_test_norm, y_test)
print("Akurasi setelah tuning:", acc_after_tuning)
# Out:
# Parameter terbaik: {'var_smoothing': 0.15199110829529336}
# Akurasi sebelum tuning: 0.6566666666666666
# Akurasi setelah tuning: 0.6666666666666666

# %% [markdown]
# Parameter terbaik: GridSearchCV telah menemukan parameter terbaik untuk model Naive Bayes Gaussian. Parameter terbaik yang ditemukan adalah {'var_smoothing': 0.15199110829529336}. Ini berarti bahwa nilai terbaik untuk parameter var_smoothing, yang mengontrol smoothing dalam model Naive Bayes Gaussian, adalah sekitar 0.152.
#
# Akurasi sebelum tuning: Ini adalah akurasi model Naive Bayes Gaussian sebelum dilakukan tuning parameter. Nilainya adalah sekitar 0.657, atau sekitar 65.7%.
#
# Akurasi setelah tuning: Ini adalah akurasi model Naive Bayes Gaussian setelah dilakukan tuning parameter menggunakan nilai terbaik yang ditemukan oleh GridSearchCV. Nilainya adalah sekitar 0.667, atau sekitar 66.7%.
